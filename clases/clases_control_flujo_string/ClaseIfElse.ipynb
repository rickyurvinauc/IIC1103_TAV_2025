# %%
print("Hola")
# Out:
# Hola

# %%
numero = int(input())

penultimo_digito = numero //10 % 10
print("el penultimo digito es: ", penultimo_digito)
# Out:
# 2
# el penultimo digito es:  0

# %%
numero = int(input())
if numero >9:
  penultimo_digito = numero //10 % 10
  print("el penultimo digito es: ", penultimo_digito)
else:
  print("solo tiene un digito")
# Out:
# 2
# solo tiene un digito

# %%
# condicion : el numero tiene AL MENOS dos digitos

numero = 100012
print("condicion 1 ",numero != numero % 10)
print("condicion 2", numero >9)
print("condicion 3", numero >=10)
# Out:
# True
# True

# %%
==, !=, >=, <, ...

# %%
numero = 2000
# verificar si es par (divisible por 2) y es divisible por 5
print("condicion par", numero % 2 == 0)
print("condicion divisible por 5", numero % 5 == 0)
print("condicion", numero % 2 == 0 and numero % 5 == 0)
# Out:
# condicion par True
# condicion divisible por 5 True
# condicion True

# %%
numero % 2 == 0 and numero % 5 == 0 or numero > 100 and numero ....

# %%
numero = int(input())
if numero % 2 == 0:
  print("numero es par")

print("linea siguiente")
# Out:
# 10
# numero es par
# linea siguiente

# %%
numero = int(input())

if numero > 0:
  print("numero es positivo")
else:
  print("numero no es positivo")
print("linea que siempre se escribe")
# Out:
# 1
# numero es positivo
# linea que siempre se escribe

# %%
# input
fecha = int(input()) #DDMM
if fecha == 1201:
  print("Tienes Interrogacion 1")
else:
  if fecha == 1901:
    print("Tienes Interrogacion 2")
  else:
    if fecha == 2601:
      print("Tienes Examen")
    else:
      print("Hoy no tienes evaluacion")
# Out:
# 1201
# Tienes Interrogacion 1

# %%
# input
fecha = int(input()) #DDMM
if fecha == 1201:
    print("Tienes Interrogacion 1")
elif fecha == 1901:
    print("Tienes Interrogacion 2")
elif fecha == 2601:
    print("Tienes Examen")
else:
    print("Hoy no tienes evaluacion")
# Out:
# 1201
# Tienes Interrogacion 1

# %%
# input
fecha = int(input()) #DDMM
if fecha == 1201:
  print("Tienes Interrogacion 1")
if fecha == 1901:
  print("Tienes Interrogacion 2")
if fecha == 2601:
  print("Tienes Examen")
if fecha != 1201 and fecha != 1901 and fecha != 2601: #fecha no es 1201 ni es 1901 ni es 2601
  print("Hoy no tienes evaluacion")
# Out:
# 1201
# Tienes Interrogacion 1

# %%
# Sacar maximo
x = int(input())
y = int(input())
z = int(input())

# Condiciones
if x> y and x >z:
  print("El mayor es:",x)
elif y>x and y >z:
  print("El mayor es:",y)
elif z>x and z>y:
  print("El mayor es:",z)
# Out:
# 10
# 2
# 1
# El mayor es: 10

# %%
mayor = x
if mayor < y:
  mayor = y
if mayor < z:
  mayor = z
print("mayor es:",mayor)
# Out:
# mayor es: 10
