# %%
2
# Out:
# 2

# %%
4
# Out:
# 4

# %%
-3
# Out:
# -3

# %%
1.3
# Out:
# 1.3

# %%
1.2
# Out:
# 1.2

# %%
'Texto"
# Out:
#   Cell In[16], line 1
#     'Texto"
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
"False"
# Out:
# 'False'

# %%
2*3
# Out:
# 6

# %%
(11//5)*5+(11%5)
# Out:
# 11

# %%
2+"2"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 2+"2"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
2+"2"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 2+"2"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
1eraVariable = 1
# Out:
#   Cell In[28], line 1
#     1eraVariable = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
numero = int(input())

# %%
ultimo_digito = numero % 10
numero_sin_ult_digito = numero //10
penultimo_digito = numero_sin_ult_digito % 10
print(penultimo_digito)
# Out:
# 4
